# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\user\OneDrive\VS CODE\PANDAS\world_population_by_country_2026.csv', index_col = 0)
print(data)
# Out:
#                Country  Population_2026  Yearly_Change  Net_Change  \
# Rank
# 1                India       1476625576           0.87  12760051.0
# 2                China       1412914089          -0.22  -3182005.0
# 3        United States        349035494           0.51   1759687.0
# 4            Indonesia        287886782           0.76   2165546.0
# 5             Pakistan        259299791           1.60   4080237.0
# ...                ...              ...            ...         ...
# 229         Montserrat             4328          -0.71       -31.0
# 230   Falkland Islands             3465          -0.12        -4.0
# 231            Tokelau             2691           3.18        83.0
# 232               Niue             1822           0.05         1.0
# 233           Holy See              506           1.00         5.0
#
#       Density_per_km2  Land_Area_km2  Migrants_Net  Fertility_Rate  \
# Rank
# 1                 497        2973190     -440456.0            1.93
# ...

# %%
print(data['Population_2026'] > 1000000000)
# Out:
# Rank
# 1       True
# 2       True
# 3      False
# 4      False
# 5      False
#        ...
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# Name: Population_2026, Length: 233, dtype: bool

# %%
is_huge = data['Population_2026'] > 190000000
data[is_huge]
# Out:
#             Country  Population_2026  Yearly_Change  Net_Change  \
# Rank
# 1             India       1476625576           0.87  12760051.0
# 2             China       1412914089          -0.22  -3182005.0
# 3     United States        349035494           0.51   1759687.0
# 4         Indonesia        287886782           0.76   2165546.0
# 5          Pakistan        259299791           1.60   4080237.0
# 6           Nigeria        242431832           2.06   4904050.0
# 7            Brazil        213562666           0.35    750261.0
#
#       Density_per_km2  Land_Area_km2  Migrants_Net  Fertility_Rate  \
# Rank
# 1                 497        2973190     -440456.0            1.93
# 2                 150        9388211     -232107.0            1.03
# 3                  38        9147420     1177848.0            1.63
# 4                 159        1811570      -39472.0            2.08
# 5                 336         770880    -1144738.0            3.44
# ...

# %%
data[data['Population_2026']>190000000]
# Out:
#             Country  Population_2026  Yearly_Change  Net_Change  \
# Rank
# 1             India       1476625576           0.87  12760051.0
# 2             China       1412914089          -0.22  -3182005.0
# 3     United States        349035494           0.51   1759687.0
# 4         Indonesia        287886782           0.76   2165546.0
# 5          Pakistan        259299791           1.60   4080237.0
# 6           Nigeria        242431832           2.06   4904050.0
# 7            Brazil        213562666           0.35    750261.0
#
#       Density_per_km2  Land_Area_km2  Migrants_Net  Fertility_Rate  \
# Rank
# 1                 497        2973190     -440456.0            1.93
# 2                 150        9388211     -232107.0            1.03
# 3                  38        9147420     1177848.0            1.63
# 4                 159        1811570      -39472.0            2.08
# 5                 336         770880    -1144738.0            3.44
# ...
